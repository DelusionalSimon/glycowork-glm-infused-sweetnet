# %% [markdown]
# To get to know glycowork I'll first get the pretrained sweetnet module working, then I'll build an evaluator for this which will allow me to do a sanity check when I am setting up my own SweetNet, and give me a
